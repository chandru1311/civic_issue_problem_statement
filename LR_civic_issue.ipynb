# %% [markdown]
# <a href="https://colab.research.google.com/github/chandru1311/MLOPS-Tasks/blob/main/LR_civic_issue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv('civic_issue_dataset.csv')

X = df[['Severity_Score', 'Num_Upvotes']]
y = df['Priority_Score']

model = LinearRegression()
model.fit(X, y)

print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
print("R² Score:", model.score(X, y))
# Out:
# Coefficients: [2.66268806 0.59168136]
# Intercept: 10.280263893056983
# R² Score: 0.6986256067239167
