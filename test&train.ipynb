# %% [markdown]
# <a href="https://colab.research.google.com/github/chandru1311/MLOPS-Tasks/blob/main/test%26train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

df = pd.read_csv("civic_issue_dataset.csv")
df.head()
# Out:
#    Report_ID Date_Submitted  Hour_of_Day       Issue_Type    Department  \
# 0  RPT-01001     2023-01-01            3  Broken Sidewalk  Public Works
# 1  RPT-01002     2023-01-01           17         Drainage  Public Works
# 2  RPT-01003     2023-01-02            6         Graffiti   Maintenance
# 3  RPT-01004     2023-01-03           12  Broken Sidewalk  Public Works
# 4  RPT-01005     2023-01-03           14      Trash/Waste    Sanitation
#
#      Zone  Severity_Score Severity_Label  Num_Upvotes  Has_Photo  \
# 0  Zone E               3           High            9          0
# 1  Zone E               4       Critical           17          0
# 2  Zone A               1            Low            1          0
# 3  Zone C               3           High            7          1
# 4  Zone B               1            Low            3          1
#
#    Has_Voice_Note  Population_Density  Dept_Current_Workload  \
# 0               1                 772                     32
# ...

# %%
X = df[["Severity_Score", "Num_Upvotes", "Has_Photo", "Population_Density"]]
y = df["Priority_Score"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_test
# Out:
#      Severity_Score  Num_Upvotes  Has_Photo  Population_Density
# 471               2            6          1                4101
# 414               1            2          1                2370
# 293               4           10          0                1967
# 321               4           13          1                1343
# 391               2            4          1                2797
# ..              ...          ...        ...                 ...
# 204               2            9          0                 878
# 248               1            6          1                4340
# 96                3           16          0                3329
# 267               3           10          1                3275
# 159               4            8          1                4718
#
# [150 rows x 4 columns]

# %%
y_test
# Out:
# 471    23.25
# 414    11.47
# 293    26.32
# 321    26.30
# 391    20.30
#        ...
# 204    12.54
# 248    18.34
# 96     27.19
# 267    25.94
# 159    29.27
# Name: Priority_Score, Length: 150, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([22.11701683, 14.16193511, 23.96528059, 27.14144372, 18.84648011,
#        32.23234675, 19.6942264 , 10.73356892, 15.54200418, 17.2259755 ,
#        21.60609243, 29.57104285, 24.99317684, 29.24658976, 21.89975535,
#        18.81989831, 15.26288441, 23.71719724, 16.45940056, 19.29221269,
#        14.568969  , 20.54405801, 18.19669873, 23.40973482, 22.26487813,
#        24.31478969, 28.33498891, 18.57430461, 17.76162101, 17.32116052,
#        15.95753341, 16.97129964, 25.18701599, 25.70789776, 21.56911887,
#        27.14473036, 26.61998595, 18.33162089, 29.06696323, 18.72432543,
#        30.05377666, 19.65552772, 23.48377337, 11.94417899, 12.8911558 ,
#        21.15777676, 20.26429847, 30.98437527, 20.63360836, 24.80671634,
#        19.23122961, 24.13606001, 20.24298875, 26.92596471, 23.85494396,
#        14.53424363, 14.90285602, 18.28279078, 24.57679768, 20.44226363,
#        22.89586109, 27.18767388, 36.70599816, 26.50182985, 22.90712804,
# ...

# %%
clf.score(X_test, y_test)
# Out:
# 0.8761535617967887

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=10)
X_test
# Out:
#      Severity_Score  Num_Upvotes  Has_Photo  Population_Density
# 151               2            4          0                2576
# 424               1            6          0                2950
# 154               2            6          1                3190
# 190               3           11          1                2244
# 131               4           12          1                 751
# ..              ...          ...        ...                 ...
# 12                2            3          1                3299
# 97                3            5          0                3845
# 130               2           11          1                4572
# 472               4           10          1                4653
# 315               4           13          1                3822
#
# [150 rows x 4 columns]
