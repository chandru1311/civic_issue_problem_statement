# %% [markdown]
# <a href="https://colab.research.google.com/github/chandru1311/MLOPS-Tasks/blob/main/multi_logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import datasets
import pandas as pd
import numpy as np
iris = datasets.load_iris()
df=pd.DataFrame(iris.data,columns=iris.feature_names)
target=iris.target

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df,target,test_size=0.2,random_state=42)
model.fit(x_train,y_train)
model.score(x_test,y_test)
# Out:
# 1.0

# %%
sample = pd.DataFrame([[3.5,3.5,3.4,3.2]], columns=df.columns)
predicted_class=model.predict(sample)[0]
iris.target_names[predicted_class]
# Out:
# np.str_('virginica')
