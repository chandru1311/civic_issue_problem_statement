# %% [markdown]
# <a href="https://colab.research.google.com/github/chandru1311/MLOPS-Tasks/blob/main/linear_reg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df = pd.read_csv('canada_per_capita_income.csv')
X = df[['year']]
y = df['per capita income (US$)']
model = LinearRegression()
model.fit(X, y)
print("Slope (m):", model.coef_[0])
print("Intercept (b):", model.intercept_)
prediction = model.predict([[2020]])
print("Predicted income in 2020: $", round(prediction[0], 2))
print("R² score:", model.score(X, y))
# Out:
# Slope (m): 828.4650752227104
# Intercept (b): -1632210.7578554575
# Predicted income in 2020: $ 41288.69
# R² score: 0.890916917957032
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
